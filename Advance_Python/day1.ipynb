# %%
import platform

# %%
print(platform.python_version())
# Out:
# 3.13.9

# %%
# integer (whole number)
num = 25

#float (decimal number)
price = 19.99

#string (text)
name = "python programming"
name1 = "1224323"

#boolean (true/false)
is_active = True

#nonetype ( represents nothing / null)
data = None

# %%
#printing all variables and their data types with new liines
print("Number:", num, "| Type:", type(num), "\n")
print("price:",price , "| Type:", type(price), "\n")
print("name:", name, "| Type:", type(name), "\n")
print("is_active:", is_active, "| Type:", type(is_active), "\n")
print("data:", data, "| Type:", type(data), "\n")
# Out:
# Number: 25 | Type: <class 'int'>
#
# price: 19.99 | Type: <class 'float'>
#
# name: python programming | Type: <class 'str'>
#
# is_active: True | Type: <class 'bool'>
#
# data: None | Type: <class 'NoneType'>
